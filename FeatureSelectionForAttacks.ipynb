# %% [markdown]
# <a href="https://colab.research.google.com/github/minhlip/Machine-Learning-IDS-CICIDS2017/blob/main/FeatureSelectionForAttacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")


# CSV files names:
csv_files=os.listdir("/content/drive/MyDrive/CSVs/attacks")

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv("/content/drive/MyDrive/CSVs/attacks/"+j)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values

    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0


    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("/content/drive/MyDrive/CSVs/feature_pics/"+j[0:-4]+".pdf",bbox_inches='tight', orientation = 'portrait', format = 'pdf', dpi=300)
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")


print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Length of Fwd Packets       0.068
# Total Backward Packets            0.064
# Bwd Packet Length Max             0.044
# Total Length of Bwd Packets       0.044
# Flow IAT Min                      0.044
# Total Fwd Packets                 0.036
# Bwd Packet Length Std             0.032
# Bwd Packet Length Mean            0.032
# Flow Duration                     0.028
# Fwd IAT Total                     0.012
# Fwd Packet Length Max             0.012
# Fwd Packet Length Std             0.000
# Fwd Packet Length Mean            0.000
# Fwd Packet Length Min             0.000
# Flow Bytes/s                      0.000
# Flow Packets/s                    0.000
# Flow IAT Mean                     0.000
# Flow IAT Std                      0.000
# Flow IAT Max                      0.000
# Bwd Packet Length Min             0.000
#
#
#
# Heartbleed=["Total Length of Fwd Packets","Total Backward Packets","Bwd Packet Length Max","Total Length of Bwd Packets","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Hulk importance list:
# DoS Hulk
#                               importance
# Features
# Bwd Packet Length Std          0.605181
# Flow IAT Min                   0.016876
# Flow Duration                  0.009385
# Fwd Packet Length Std          0.001848
# Fwd Packet Length Max          0.001607
# Fwd IAT Total                  0.001475
# Flow Bytes/s                   0.001203
# Flow Packets/s                 0.000961
# Flow IAT Max                   0.000857
# Flow IAT Mean                  0.000749
# Flow IAT Std                   0.000487
# Total Fwd Packets              0.000472
# Total Length of Bwd Packets    0.000463
# Total Backward Packets         0.000329
# Bwd Packet Length Mean         0.000035
# Bwd Packet Length Min          0.000032
# Bwd Packet Length Max          0.000016
# Total Length of Fwd Packets    0.000015
# Fwd Packet Length Mean         0.000006
# Fwd Packet Length Min          0.000002
#
#
#
# DoS Hulk=["Bwd Packet Length Std","Flow IAT Min","Flow Duration","Fwd Packet Length Std","Fwd Packet Length Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Bwd Packet Length Std          0.584002
# Flow IAT Min                   0.254885
# Flow IAT Mean                  0.035571
# Total Backward Packets         0.007675
# Flow IAT Std                   0.007403
# Fwd Packet Length Min          0.005956
# Flow Bytes/s                   0.001650
# Fwd Packet Length Max          0.001650
# Fwd Packet Length Mean         0.001261
# Total Length of Fwd Packets    0.001157
# Fwd IAT Total                  0.000954
# Flow Duration                  0.000838
# Flow IAT Max                   0.000526
# Flow Packets/s                 0.000485
# Total Length of Bwd Packets    0.000220
# Bwd Packet Length Mean         0.000164
# Total Fwd Packets              0.000038
# Bwd Packet Length Max          0.000026
# Fwd Packet Length Std          0.000024
# Bwd Packet Length Min          0.000010
#
#
#
# DoS GoldenEye=["Bwd Packet Length Std","Flow IAT Min","Flow IAT Mean","Total Backward Packets","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Total Length of Fwd Packets    0.350246
# Flow Bytes/s                   0.313159
# Bwd Packet Length Std          0.000355
# Total Fwd Packets              0.000179
# Fwd Packet Length Std          0.000072
# Fwd Packet Length Max          0.000071
# Fwd Packet Length Min          0.000054
# Flow IAT Min                   0.000046
# Flow IAT Mean                  0.000042
# Fwd Packet Length Mean         0.000040
# Flow Duration                  0.000038
# Fwd IAT Total                  0.000031
# Flow IAT Max                   0.000030
# Total Backward Packets         0.000024
# Flow Packets/s                 0.000019
# Bwd Packet Length Min          0.000016
# Bwd Packet Length Mean         0.000009
# Flow IAT Std                   0.000009
# Total Length of Bwd Packets    0.000006
# Bwd Packet Length Max          0.000006
#
#
#
# PortScan=["Total Length of Fwd Packets","Flow Bytes/s","Bwd Packet Length Std","Total Fwd Packets","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Flow Bytes/s                   0.424300
# Flow IAT Min                   0.063493
# Flow IAT Mean                  0.021997
# Bwd Packet Length Min          0.003367
# Flow Packets/s                 0.003092
# Flow Duration                  0.002932
# Flow IAT Max                   0.002477
# Flow IAT Std                   0.002298
# Total Length of Fwd Packets    0.000993
# Fwd Packet Length Max          0.000469
# Fwd IAT Total                  0.000331
# Total Backward Packets         0.000185
# Total Fwd Packets              0.000153
# Fwd Packet Length Mean         0.000150
# Fwd Packet Length Std          0.000138
# Total Length of Bwd Packets    0.000094
# Bwd Packet Length Max          0.000064
# Bwd Packet Length Std          0.000042
# Fwd Packet Length Min          0.000025
# Bwd Packet Length Mean         0.000015
#
#
#
# SSH-Patator=["Flow Bytes/s","Flow IAT Min","Flow IAT Mean","Bwd Packet Length Min","Flow Packets/s"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Flow Packets/s                 0.654793
# Fwd Packet Length Min          0.110303
# Bwd Packet Length Std          0.041384
# Bwd Packet Length Mean         0.038511
# Fwd Packet Length Std          0.016328
# Fwd Packet Length Mean         0.010035
# Flow IAT Mean                  0.009323
# Total Length of Bwd Packets    0.004067
# Bwd Packet Length Max          0.003973
# Flow IAT Min                   0.002667
# Fwd Packet Length Max          0.001405
# Total Fwd Packets              0.000742
# Total Length of Fwd Packets    0.000677
# Flow Bytes/s                   0.000618
# Bwd Packet Length Min          0.000557
# Flow Duration                  0.000547
# Flow IAT Max                   0.000537
# Fwd IAT Total                  0.000439
# Flow IAT Std                   0.000104
# Total Backward Packets         0.000090
#
#
#
# DoS Slowhttptest=["Flow Packets/s","Fwd Packet Length Min","Bwd Packet Length Std","Bwd Packet Length Mean","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.543463
# Total Backward Packets         0.102715
# Total Length of Fwd Packets    0.008641
# Fwd Packet Length Max          0.002295
# Fwd Packet Length Std          0.000374
# Bwd Packet Length Min          0.000235
# Flow IAT Min                   0.000227
# Flow Duration                  0.000185
# Flow IAT Max                   0.000152
# Fwd IAT Total                  0.000147
# Flow IAT Std                   0.000141
# Flow Bytes/s                   0.000141
# Flow IAT Mean                  0.000102
# Flow Packets/s                 0.000086
# Fwd Packet Length Min          0.000084
# Bwd Packet Length Mean         0.000059
# Total Length of Bwd Packets    0.000055
# Fwd Packet Length Mean         0.000050
# Bwd Packet Length Max          0.000045
# Total Fwd Packets              0.000006
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Total Length of Fwd Packets","Fwd Packet Length Max","Fwd Packet Length Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Length of Fwd Packets    0.190096
# Fwd Packet Length Std          0.060975
# Flow Duration                  0.056148
# Fwd Packet Length Mean         0.046461
# Flow IAT Max                   0.033781
# Fwd IAT Total                  0.018742
# Flow IAT Min                   0.017577
# Fwd Packet Length Max          0.012400
# Bwd Packet Length Mean         0.009217
# Bwd Packet Length Std          0.008062
# Flow Bytes/s                   0.007866
# Flow IAT Mean                  0.006444
# Flow IAT Std                   0.006329
# Flow Packets/s                 0.005267
# Bwd Packet Length Max          0.004057
# Fwd Packet Length Min          0.001879
# Bwd Packet Length Min          0.001649
# Total Backward Packets         0.001439
# Total Fwd Packets              0.000752
# Total Length of Bwd Packets    0.000482
#
#
#
# Infiltration=["Total Length of Fwd Packets","Fwd Packet Length Std","Flow Duration","Fwd Packet Length Mean","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Fwd Packet Length Std          0.024232
# Fwd Packet Length Max          0.006363
# Bwd Packet Length Max          0.001230
# Bwd Packet Length Mean         0.000333
# Flow IAT Min                   0.000164
# Total Length of Bwd Packets    0.000131
# Bwd Packet Length Std          0.000081
# Fwd Packet Length Mean         0.000079
# Flow Duration                  0.000078
# Total Length of Fwd Packets    0.000074
# Flow IAT Mean                  0.000074
# Flow Packets/s                 0.000073
# Flow IAT Max                   0.000072
# Total Fwd Packets              0.000071
# Fwd IAT Total                  0.000070
# Total Backward Packets         0.000047
# Flow IAT Std                   0.000016
# Flow Bytes/s                   0.000008
# Fwd Packet Length Min          0.000006
# Bwd Packet Length Min          0.000002
#
#
#
# FTP-Patator=["Fwd Packet Length Std","Fwd Packet Length Max","Bwd Packet Length Max","Bwd Packet Length Mean","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.481773
# Bwd Packet Length Mean         0.134185
# Total Fwd Packets              0.030031
# Flow IAT Min                   0.014904
# Total Length of Bwd Packets    0.006427
# Fwd IAT Total                  0.002653
# Fwd Packet Length Max          0.001629
# Bwd Packet Length Std          0.001607
# Bwd Packet Length Max          0.001546
# Flow Bytes/s                   0.001229
# Flow IAT Max                   0.001075
# Fwd Packet Length Std          0.000862
# Flow Packets/s                 0.000848
# Total Backward Packets         0.000650
# Flow Duration                  0.000629
# Fwd Packet Length Mean         0.000585
# Total Length of Fwd Packets    0.000328
# Flow IAT Std                   0.000235
# Fwd Packet Length Min          0.000105
# Bwd Packet Length Min          0.000017
#
#
#
# DoS slowloris=["Flow IAT Mean","Bwd Packet Length Mean","Total Fwd Packets","Flow IAT Min","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Flow IAT Min                   0.007663
# Flow IAT Max                   0.005884
# Flow Duration                  0.005705
# Total Length of Fwd Packets    0.005195
# Flow IAT Mean                  0.004751
# Flow Packets/s                 0.004617
# Bwd Packet Length Std          0.003677
# Flow IAT Std                   0.002792
# Bwd Packet Length Max          0.002530
# Fwd Packet Length Mean         0.001746
# Fwd IAT Total                  0.001213
# Fwd Packet Length Max          0.000976
# Total Fwd Packets              0.000819
# Fwd Packet Length Std          0.000714
# Flow Bytes/s                   0.000360
# Bwd Packet Length Mean         0.000287
# Total Length of Bwd Packets    0.000121
# Total Backward Packets         0.000116
# Bwd Packet Length Min          0.000011
# Fwd Packet Length Min          0.000008
#
#
#
# Web Attack=["Flow IAT Min","Flow IAT Max","Flow Duration","Total Length of Fwd Packets","Flow IAT Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  8655.156291484833 seconds
